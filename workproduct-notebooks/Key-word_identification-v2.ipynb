# %%
# ADD
# Add subject and object (to identify nouns not otherwise identified)
# Remove duplicated searchTerms (keep first)

# %%
import pandas as pd
import spacy
from string import punctuation, digits
import re

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 1000)

# %%
# Question data
t_data = pd.read_pickle('C:/Users/Fredi/Kodningsprojekt/data-analysis/workproduct-files/cleaned-dataframes/t_dataMaster-duplicatesRemoved.pkl')

# %%
# word frequency data
word_frequencies = pd.read_csv("F:/Word frequencies/unigram_freq.csv")

# %%
nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Functions

# %%
def namedEntities(a):
    doc = nlp(a)
    toReturn = []
    
    #If input is title-case, convert to sentence
    if a.istitle():
        a = a.capitalize()
    
    for ent in doc.ents:
        toReturn.append((ent.text, ent.label_))

    return toReturn

# %%
def getNouns(a):
    
    #Identify substrings between quotes
    
    quotes1 = re.compile('"[^"]*"')
    quotes2 = re.compile("'[^']*'")
    quoteRanges = []
    toReturn = []
    
    for value in quotes1.finditer(a):
        quoteRanges.append(value.span())
        toReturn.append(value.group()[1:-1])
    for value in quotes2.finditer(a):
        quoteRanges.append(value.span())
        toReturn.append(value.group()[1:-1])
    
    #If input is title-case, convert to sentence
    if a.istitle():
        a = a.capitalize()
    
    doc = nlp(a)
    pos_tag = ['NOUN']
    
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        
        #Exclude words within quotes
        if any(start <= token.idx <= end for (start, end) in quoteRanges):
            continue
        
        if(token.pos_ in pos_tag):
            toReturn.append(token.lemma_)
    
    return toReturn

# %%
def getSubjects(a):
    doc = nlp(a.lower())
    toReturn = []
    dep_tag = ['csubj', 'nsubj']
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.dep_ in dep_tag):
            toReturn.append(token.lemma_)
    
    return toReturn

# %%
def getObjects(a):
    doc = nlp(a.lower())
    toReturn = []
    dep_tag = ['iobj', 'obj', 'dobj', 'pobj']
    for token in doc:
        if(token.text in nlp.Defaults.stop_words or token.text in punctuation):
            continue
        if(token.dep_ in dep_tag):
            toReturn.append(token.lemma_)
    
    return toReturn

# %%
def frequencyCount(a):
    result = []
    for word in a:
        try:
            result.append([word, word_frequencies.loc[word_frequencies["word"] == word, "count"].iloc[0] ])
        except IndexError:
            # If no count is found, add 0 as value to ensure being sorted first in searchTerms()
            result.append([word, 0])
    return result

# %%
# FUNCTION: Identify wikipedia redirect terms to look for (in priority order)
# 1. Check if named entities exist and add in order of priority (WORK_OF_ART, PERSON, FAC, LOC)
# 2. Add nouns in ascending frequency order (rarest first)
# 3. Remove "the" / "a" / "an" / quotes from beginning of named entities

# Takes a question row as input


def searchTerms(a):
    result = []
    
    for ent in a["namedEntities"]:
        if ent[1] == "WORK_OF_ART":
            result.append(ent[0])
    for ent in a["namedEntities"]:
        if ent[1] == "PERSON":
            result.append(ent[0])    
    for ent in a["namedEntities"]:
        if ent[1] == "FAC" or ent[1] == "LOC":
            result.append(ent[0])
    
    # sort nouns by nounFrequencies
    # https://www.kite.com/python/answers/how-to-sort-a-list-of-lists-by-an-index-of-each-inner-list-in-python
    # sorted_list = sorted(nested_list, key=lambda x: x[1])
    nounsSorted = sorted(a["nouns"], key=lambda x: x[1])
    for noun in nounsSorted:
        result.append(noun[0])
        
    # Clean-up, iterate over each value in result list          
    for i in range(len(result)):
        try:
            if result[i][:4].lower() == "the ":
                result[i] = result[i][4:]
            if result[i][:2].lower() == "a ":
                result[i] = result[i][2:]
            if result[i][:3].lower() == "an ":
                result[i] = result[i][3:]
            if result[i][0].lower() == "'" or result[i][0].lower() == '"':
                result[i] = result[i][1:]
            if result[i][-1].lower() == "'" or result[i][-1].lower() == '"':
                result[i] = result[i][:-1]
            if result[i][-2:].lower() == "'s":
                result[i] = result[i][:-2]
        except:
            continue
    return result

# %% [markdown]
# #### Identifying key words

# %%
questions = t_data

# %%
# %%time
questions["namedEntities"] = questions["CONS_question"].apply(lambda x: namedEntities(x))
# Out:
# Wall time: 6min 43s

# %%
# %%time
questions["nouns"] = questions["CONS_question"].apply(lambda x: getNouns(x))
# Out:
# Wall time: 7min 1s

# %%
# %%time
# Add frequency count to nouns
questions["nouns"] = questions["nouns"].apply(lambda x: frequencyCount(x))
# Out:
# Wall time: 39min 47s

# %%
# %%time
questions["searchTerms"] = questions.apply(searchTerms, axis = 1)
# Out:
# Wall time: 4.79 s

# %%
questions.to_pickle("../workproduct-files/t_dataMaster-keywordsIdentified.pkl")

# %%
questions[7::100][300:400]
# Out:
#             CONS_id  \
# 30007  tdb_0x007cdb
# 30107  tdb_0x007d44
# 30207  tdb_0x007db1
# 30307  tdb_0x007eb5
# 30407  tdb_0x007f43
# 30507  tdb_0x007fb0
# 30607  tdb_0x008015
# 30707  tdb_0x008079
# 30807  tdb_0x0080df
# 30907  tdb_0x008143
# 31007  tdb_0x0081a9
# 31107  tdb_0x008219
# 31207  tdb_0x008284
# 31307  tdb_0x0082ed
# 31407  tdb_0x00835a
# 31507  tdb_0x0083c3
# 31607  tdb_0x008429
# 31707  tdb_0x008497
# 31807  tdb_0x008508
# 31907  tdb_0x008572
# 32007  tdb_0x0085e4
# 32107  tdb_0x00864f
# 32207  tdb_0x0086b6
# 32307  tdb_0x008728
# 32407  tdb_0x00878f
# 32507  tdb_0x0087f4
# 32607  tdb_0x00885c
# 32707  tdb_0x0088c7
# 32807  tdb_0x008932
# 32907  tdb_0x008996
# 33007  tdb_0x0089fe
# 33107  tdb_0x008a66
# 33207  tdb_0x008acd
# 33307  tdb_0x008b38
# 33407  tdb_0x008ba1
# 33507  tdb_0x008c0b
# 33607  tdb_0x008c77
# 33707  tdb_0x008ce0
# 33807  tdb_0x008d4c
# 33907  tdb_0x008dbb
# 34007  tdb_0x008e24
# 34107  tdb_0x008e8d
# 34207  tdb_0x008ef6
# 34307  tdb_0x008f62
# 34407  tdb_0x008fd8
# 34507  tdb_0x009042
# 34607  tdb_0x0090b4
# 34707  tdb_0x009124
# 34807  tdb_0x009190
# 34907  tdb_0x009200
# 35007  tdb_0x009266
# 35107  tdb_0x0092d2
# 35207  tdb_0x009337
# 35307  tdb_0x00939b
# 35407  tdb_0x009404
# 35507  tdb_0x00946f
# 35607  tdb_0x0094dc
# 35707  tdb_0x009544
# 35807  tdb_0x0095ae
# 35907  tdb_0x00961d
# 36007  tdb_0x00968d
# 36107  tdb_0x009702
# 36207  tdb_0x009771
# 36307  tdb_0x0097e1
# 36407  tdb_0x009847
# 36507  tdb_0x0098ac
# 36607  tdb_0x009913
# 36707  tdb_0x00997a
# 36807  tdb_0x0099e0
# 36907  tdb_0x009a46
# 37007  tdb_0x009aae
# 37107  tdb_0x009b13
# 37207  tdb_0x009b81
# 37307  tdb_0x009be9
# 37407  tdb_0x009c56
# 37507  tdb_0x009cbb
# 37607  tdb_0x009d22
# 37707  tdb_0x009d8a
# 37807  tdb_0x009def
# 37907  tdb_0x009e56
# 38007  tdb_0x009eca
# 38107  tdb_0x009f2e
# 38207  tdb_0x009f9a
# 38307  tdb_0x00a003
# 38407  tdb_0x00a06b
# 38507  tdb_0x00a0d2
# 38607  tdb_0x00a13b
# 38707  tdb_0x00a1a4
# 38807  tdb_0x00a20a
# 38907  tdb_0x00a274
# 39007  tdb_0x00a2dc
# 39107  tdb_0x00a34e
# 39207  tdb_0x00a3bf
# 39307  tdb_0x00a42d
# 39407  tdb_0x00a4a4
# 39507  tdb_0x00a513
# 39607  tdb_0x00a580
# 39707  tdb_0x00a5f8
# 39807  tdb_0x00a667
# 39907  tdb_0x00a6d5
#
#                                                                                                             CONS_question  \
# 30007                                                                                                     What is Ordune?
# 30107                                      What is the 1983 bryan adams album which features the hit 'cuts like a knife'?
# 30207                                                                                              What is the bundestag?
# 30307                                                                       What is the capital of Sao Tome and Principe?
# 30407                                                                  What is the commonest item traded internationally?
# 30507                                    What is the equivalent RAF rank to Sub-lieutenant RN and Lieutenant in the army?
# 30607                                                                              What is the fear of lawsuits known as?
# 30707                                                               What is the fear of teeth or dental surgery known as?
# 30807                                                                       What is the flower that stands for: argument?
# 30907                                                                        What is the flower that stands for: poverty?
# 31007                                                                                      What is the german parliament?
# 31107                                                                          What Is The Largest Living Land Carnivore?
# 31207                                                             What is the magazine of the Jehovah's Witnesses called?
# 31307                                                                      What is the more common name of nitrous oxide?
# 31407                                                                            What is the most rural state in the USA?
# 31507                                                                     What is the name of Mighty Mouse's girl friend?
# 31607                                                             What is the name of the mountain range in North Africa?
# 31707                                                                            What is the nickname for South Carolina?
# 31807                             What is the only letter of the English alphabet with three syllables (no hints please)?
# 31907                                                                                What is the Roman Numerals for 4000?
# 32007                                                     What is the stage name of film actress Caryn Johnson born 1949?
# 32107                                                                           What is the term for a castrated rooster?
# 32207                                                                                    What is the world tallest horse?
# 32307                                                         What is tramp's nickname for lady in 'Lady and the Tramp''?
# 32407                                                                        What key is to the right of T on a keyboard?
# 32507                                                                      What kind of shark has killed the most people?
# 32607                                                            What links Hof Malomo Zagreb Belgrade Porto Varna Vevey?
# 32707                                                                       What martial art's name means 'leisure time'?
# 32807                                                     What mythological animal was the insignia of UK Airborne WW II?
# 32907                                                                            What nationality is athlete Greta Waitz?
# 33007                                                            What note is placed on the centre line of a treble clef?
# 33107                                           What part of an eatery do some restaurant owners call 'the cancer ward''?
# 33207                                                                                      What plant is snuff made from?
# 33307                                                                         What queen banned mirrors as she got older?
# 33407                                                    What scene is included for good luck in most of Spielberg films?
# 38807                                                        Which TV Show Has The Theme Tune 'The Best Of Both Worlds''?
# 38907                                                          Which USA record producer played maracas Stones 1st album?
# 39007                                                                    Which writer created Detective-Inspector Bucket?
# 39107  Who began his career with 'the yardbirds' and is established as one of the best rock guitarists of his generation?
# 39207                                                                            Who composed the Symphonies Fantastique?
# 39307                                                                         Who did henry winkler play in 'happy days'?
# 39407                                                                                           Who does a Filicide kill?
# 39507                                                                  Who got a gold single for the song Daniel in 1973?
# 39607                                                                                       Who invented false eyelashes?
# 39707                                        Who is fond of saying 'i will gladly pay you tuesday for a hamburger today'?
# 39807                                                                           Who is the greek counterpart of hercules?
# 39907                                                                          Who is the roman counterpart of aphrodite?
#
#                                 CONS_answer CONS_alt answers  \
# 30007                  Arousal by nude pics              NaN
# 30107                     Cuts like a knife              NaN
# 30207                     German parliament              NaN
# 30307                              Sao tome              NaN
# 30407         Petroleum and its by products              NaN
# 30507                        Flying officer              NaN
# 30607                          Liticaphobia              NaN
# 30707                          Odontophobia              NaN
# 30807                                   Fig              NaN
# 30907                    Evergreen clematis              NaN
# 31007                             Bundestag              NaN
# 31107                          Grizzly Bear              NaN
# 31207                        The Watchtower              NaN
# 31307                          Laughing gas              NaN
# 31407                          North Dakota              NaN
# 31507                       Pearl Pureheart              NaN
# 31607                       Atlas mountains              NaN
# 31707                        Palmetto state              NaN
# 31807                                     W              NaN
# 31907                                  MMMM              NaN
# 32007                       Whoopi goldberg              NaN
# 32107                                 Capon              NaN
# 32207                           Shire Horse              NaN
# 32307                                 Pidge              NaN
# 32407                                     Y              NaN
# 32507                           Great white              NaN
# 32607          International film festivals              NaN
# 32707                               Kung fu              NaN
# 32807         Pegasus – carrying Beleraphon              NaN
# 32907                             Norwegian              NaN
# 33007                                     B              NaN
# 33107   The smoking section smoking section              NaN
# 33207                               Tobacco              NaN
# 33307                         Elizabeth 1st              NaN
# 33407                       A Shooting star              NaN
# 33507                     All in the family              NaN
# 33607                      88 miles an hour              NaN
# 33707                                 Texas              NaN
# 33807                                4.30pm              NaN
# 33907                               Captain              NaN
# 34007                     Dwight eisenhower              NaN
# 34107                           Mississippi              NaN
# 34207                                Darkie              NaN
# 34307                      Mussolini's Body              NaN
# 34407        Beatles Sergeant Peppers cover              NaN
# 34507          Delaware Pennsylvania second              NaN
# 34607                            Water Polo              NaN
# 34707                        Admiral Benbow              NaN
# 34807                           Shady Pines              NaN
# 34907                     Annie mae bullock              NaN
# 35007                                 Roger              NaN
# 35107                        St Leger Gould              NaN
# 35207            Play it - type of woodwind              NaN
# 35307                               Saffron              NaN
# 35407                             Stockholm              NaN
# 35507                              Samantha              NaN
# 35607                              A colony              NaN
# 35707                            20 minutes              NaN
# 35807                                  1953              NaN
# 35907                     New grand theater              NaN
# 36007                                 Wrist              NaN
# 36107                              The face              NaN
# 36207                              Zanzibar              NaN
# 36307                            Bangladesh              NaN
# 36407                                Putter              NaN
# 36507                       Kathleen turner              NaN
# 36607                             Springbok              NaN
# 36707                               Tootise              NaN
# 36807                               Bristol              NaN
# 36907                                Chekov              NaN
# 37007                     Felix Mendelssohn              NaN
# 37107                          Dolly parton              NaN
# 36407         Uncategorized                            NaN
# 36507         Uncategorized                            NaN
# 36607         Uncategorized                            NaN
# 36707         Uncategorized                            NaN
# 36807         Uncategorized                            NaN
# 36907         Uncategorized                            NaN
# 37007         Uncategorized                            NaN
# 37107         Uncategorized                            NaN
# 37207         Uncategorized                            NaN
# 37307         Uncategorized                            NaN
# 37407         Uncategorized                            NaN
# 37507         Uncategorized                            NaN
# 37607         Uncategorized                            NaN
# 37707         Uncategorized                            NaN
# 37807         Uncategorized                            NaN
# 37907         Uncategorized                            NaN
# 38007         Uncategorized                            NaN
# 38107         Uncategorized                            NaN
# 38207         Uncategorized                            NaN
# 38307         Uncategorized                            NaN
# 38407         Uncategorized                            NaN
# 38507         Uncategorized                            NaN
# 38607         Uncategorized                            NaN
# 38707         Uncategorized                            NaN
# 38807         Uncategorized                            NaN
# 38907         Uncategorized                            NaN
# 39007         Uncategorized                            NaN
# 39107         Uncategorized                            NaN
# 39207         Uncategorized                            NaN
# 39307         Uncategorized                            NaN
# 39407         Uncategorized                            NaN
# 39507         Uncategorized                            NaN
# 39607         Uncategorized                            NaN
# 39707         Uncategorized                            NaN
# 39807         Uncategorized                            NaN
# 39907         Uncategorized                            NaN
#
#       CONS_type-formulation CONS_type-multipleChoice       ORIG_id  \
# 30007              Question                    False  tdb_0x007cdb
# 30107              Question                    False  tdb_0x007d44
# 30207              Question                    False  tdb_0x007db1
# 30307              Question                    False  tdb_0x007eb5
# 30407              Question                    False  tdb_0x007f43
# 30507              Question                    False  tdb_0x007fb0
# 30607              Question                    False  tdb_0x008015
# 30707              Question                    False  tdb_0x008079
# 30807              Question                    False  tdb_0x0080df
# 30907              Question                    False  tdb_0x008143
# 31007              Question                    False  tdb_0x0081a9
# 31107              Question                    False  tdb_0x008219
# 31207              Question                    False  tdb_0x008284
# 31307              Question                    False  tdb_0x0082ed
# 31407              Question                    False  tdb_0x00835a
# 31507              Question                    False  tdb_0x0083c3
# 31607              Question                    False  tdb_0x008429
# 31707              Question                    False  tdb_0x008497
# 31807              Question                    False  tdb_0x008508
# 31907              Question                    False  tdb_0x008572
# 32007              Question                    False  tdb_0x0085e4
# 32107              Question                    False  tdb_0x00864f
# 32207              Question                    False  tdb_0x0086b6
# 32307              Question                    False  tdb_0x008728
# 32407              Question                    False  tdb_0x00878f
# 32507              Question                    False  tdb_0x0087f4
# 32607              Question                    False  tdb_0x00885c
# 32707              Question                    False  tdb_0x0088c7
# 32807              Question                    False  tdb_0x008932
# 32907              Question                    False  tdb_0x008996
# 33007              Question                    False  tdb_0x0089fe
# 33107              Question                    False  tdb_0x008a66
# 33207              Question                    False  tdb_0x008acd
# 33307              Question                    False  tdb_0x008b38
# 33407              Question                    False  tdb_0x008ba1
# 33507              Question                    False  tdb_0x008c0b
# 33607              Question                    False  tdb_0x008c77
# 33707      Statement - open                    False  tdb_0x008ce0
# 33807              Question                    False  tdb_0x008d4c
# 33907              Question                    False  tdb_0x008dbb
# 34007              Question                    False  tdb_0x008e24
# 34107              Question                    False  tdb_0x008e8d
# 34207              Question                    False  tdb_0x008ef6
# 34307              Question                    False  tdb_0x008f62
# 34407              Question                    False  tdb_0x008fd8
# 34507              Question                    False  tdb_0x009042
# 34607              Question                    False  tdb_0x0090b4
# 34707              Question                    False  tdb_0x009124
# 34807      Statement - open                    False  tdb_0x009190
# 34907              Question                    False  tdb_0x009200
# 35007              Question                    False  tdb_0x009266
# 35107              Question                    False  tdb_0x0092d2
# 35207              Question                    False  tdb_0x009337
# 35307              Question                    False  tdb_0x00939b
# 35407              Question                    False  tdb_0x009404
# 35507              Question                    False  tdb_0x00946f
# 35607              Question                    False  tdb_0x0094dc
# 35707              Question                    False  tdb_0x009544
# 35807              Question                    False  tdb_0x0095ae
# 35907              Question                    False  tdb_0x00961d
# 36007              Question                    False  tdb_0x00968d
# 36107              Question                    False  tdb_0x009702
# 36207              Question                    False  tdb_0x009771
# 36307              Question                    False  tdb_0x0097e1
# 36407      Statement - open                    False  tdb_0x009847
# 36507              Question                    False  tdb_0x0098ac
# 36607              Question                    False  tdb_0x009913
# 36707              Question                    False  tdb_0x00997a
# 36807              Question                    False  tdb_0x0099e0
# 36907              Question                    False  tdb_0x009a46
# 37007              Question                    False  tdb_0x009aae
# 37107              Question                    False  tdb_0x009b13
# 37207              Question                    False  tdb_0x009b81
# 37307              Question                    False  tdb_0x009be9
# 37407              Question                    False  tdb_0x009c56
# 37507              Question                    False  tdb_0x009cbb
# 37607              Question                    False  tdb_0x009d22
# 37707              Question                    False  tdb_0x009d8a
# 37807              Question                    False  tdb_0x009def
# 37907              Question                    False  tdb_0x009e56
# 38007              Question                    False  tdb_0x009eca
# 38107              Question                    False  tdb_0x009f2e
# 38207              Question                    False  tdb_0x009f9a
# 38307              Question                    False  tdb_0x00a003
# 38407              Question                    False  tdb_0x00a06b
# 38507              Question                    False  tdb_0x00a0d2
# 38607              Question                    False  tdb_0x00a13b
# 38707              Question                    False  tdb_0x00a1a4
# 38807              Question                    False  tdb_0x00a20a
# 38907              Question                    False  tdb_0x00a274
# 39007              Question                    False  tdb_0x00a2dc
# 39107              Question                    False  tdb_0x00a34e
# 39207              Question                    False  tdb_0x00a3bf
# 39307              Question                    False  tdb_0x00a42d
# 39407              Question                    False  tdb_0x00a4a4
# 39507              Question                    False  tdb_0x00a513
# 39607              Question                    False  tdb_0x00a580
# 39707              Question                    False  tdb_0x00a5f8
# 39807              Question                    False  tdb_0x00a667
# 39907              Question                    False  tdb_0x00a6d5
#
#                                                                                                             ORIG_question  \
# 30007                                                                                                      What is Ordune
# 30107                                       What is the 1983 bryan adams album which features the hit 'cuts like a knife'
# 30207                                                                                               What is the bundestag
# 30307                                                                       What is the Capital of: Sao Tome and Principe
# 30407                                                                   What is the commonest item traded internationally
# 30507                                     What is the equivalent RAF rank to Sub-lieutenant RN and Lieutenant in the army
# 30607                                                                               What is the fear of lawsuits known as
# 30707                                                                What is the fear of teeth or dental surgery known as
# 30807                                                                        What is the flower that stands for: argument
# 30907                                                                         What is the flower that stands for: poverty
# 31007                                                                                       What is the german parliament
# 31107                                                                           What Is The Largest Living Land Carnivore
# 31207                                                              What is the magazine of the Jehovah's Witnesses called
# 31307                                                                       What is the more common name of nitrous oxide
# 36307                                                                                                                  [[child, 119747393], [final, 97649084]]
# 36407                                                                                                    [[whet, 267569], [golf, 88332962], [club, 132428495]]
# 36507                                                                                                                  [[actress, 7010056], [film, 116097842]]
# 36607                                                                                                                     [[animal, 62566660], [pronk, 68612]]
# 36707                                                                                                                [[Hey Can I Try On Your Yellow Dress, 0]]
# 36807  [[aircraft, 24745739], [company, 324272258], [car, 264720374], [marque, 605877], [bus, 41043865], [truck, 32136249], [war, 126517399], [era, 16930615]]
# 36907                                                                                                             [[character, 52028227], [cartoon, 19615945]]
# 37007                                                                                                                                    [[composer, 8839743]]
# 37107                                                                            [[It takes an awful lot of money to look this cheap., 0], [singer, 12021075]]
# 37207                                                                                                                                   [[country, 188691168]]
# 37307                                                                                                                       [[play well, 0], [word, 98671341]]
# 37407                                                                                                                   [[monarch, 2537590], [reign, 3505605]]
# 37507                                                                                                 [[pop, 54140138], [group, 321842984], [thing, 97451660]]
# 37607                                                                                                                [[film, 116097842], [picture, 124116581]]
# 37707                                                                                                  [[gangster, 1167811], [jail, 7515955], [gun, 22834049]]
# 37807                                                                                     [[Thank You For Loving Me, 0], [group, 321842984], [song, 65832126]]
# 37907                                                                                                                                       [[town, 90478880]]
# 38007                                                                                                              [[island, 102316998], [wildlife, 23847419]]
# 38107                                                                                                                                      [[city, 390564835]]
# 38207                                                                                                                                    [[musician, 6011315]]
# 38307                                                                                                                [[officer, 48483165], [platoon, 1139832]]
# 38407                                           [[platinum, 15499095], [selling, 44375770], [artist, 67421654], [assassination, 2116496], [attempt, 25251906]]
# 38507                                                                                                                                      [[river, 78843808]]
# 38607                                                                                                         [[singer, 12021075], [hit, 53171478], [1980, 0]]
# 38707                                                                                                                                   [[company, 324272258]]
# 38807                                                                                       [[The Best Of Both Worlds, 0], [tv, 159603914], [show, 247541986]]
# 38907                                                                                           [[record, 102234743], [producer, 16730305], [album, 77914316]]
# 39007                                                                                                                                     [[writer, 29320566]]
# 39107                                                 [[the yardbirds, 0], [career, 71248807], [rock, 95488543], [guitarist, 2713559], [generation, 39912229]]
# 39207                                                                                                                                                       []
# 39307                                                                                                                                        [[happy days, 0]]
# 39407                                                                                                                                       [[kill, 24850951]]
# 39507                                                                                                                    [[gold, 107497778], [song, 65832126]]
# 39607                                                                                                                                      [[eyelash, 387907]]
# 39707                                                                                               [[i will gladly pay you tuesday for a hamburger today, 0]]
# 39807                                                                                                                                 [[counterpart, 1899186]]
# 39907                                                                                                                                 [[counterpart, 1899186]]
#
#                                                            searchTerms
# 30007                                                         [Ordune]
# 30107                                         [cuts like a knife, hit]
# 30207                                                      [bundestag]
# 30307                                                        [capital]
# 30407                                                           [item]
# 30507                                         [lieutenant, rank, army]
# 30607                                                  [lawsuit, fear]
# 30707                                           [tooth, fear, surgery]
# 30807                                               [flower, argument]
# 30907                                                [poverty, flower]
# 31007                                                     [parliament]
# 31107                                                [carnivore, land]
# 31207                                                       [magazine]
# 31307                                                          [oxide]
# 31407                                                          [state]
# 31507                                     [Mighty Mouse, girl, friend]
# 31607                                                [mountain, range]
# 31707                                                       [nickname]
# 31807                               [syllable, alphabet, hint, letter]
# 31907                                                               []
# 32007                                  [Johnson, actress, stage, film]
# 32107                                                  [rooster, term]
# 32207                                                   [horse, world]
# 32307                                      [s nickname for lady in , ]
# 32407                                        [keyboard, key, right, t]
# 32507                                            [shark, kind, people]
# 32607                                 [Hof Malomo, Porto, Varna Vevey]
# 32707                                       [s name means , art, time]
# 32807                               [Airborne WW II, insignia, animal]
# 32907                              [Greta Waitz, nationality, athlete]
# 33007                                       [clef, centre, note, line]
# 33107                         [cancer ward, eatery, restaurant, owner]
# 33207                                                          [plant]
# 33307                                                         [mirror]
# 33407                                   [Spielberg, luck, scene, film]
# 33507                                         [mike stivic, character]
# 33607                                        [capacitor, speed, order]
# 33707                                                          [state]
# 33807                             [clock, newspaper, time, time, page]
# 33907                [love will keep us together, song, person, group]
# 34007                                          [robert montgomery, tv]
# 34107                                [1990, abolition, slavery, state]
# 34207                                                 [Black Beauties]
# 34307                                                         [loreto]
# 34407                               [Peter Blake, designer, art, work]
# 34507                                                   [union, state]
# 34607                                                    [sport, team]
# 34707                                                            [inn]
# 34807                   [Sofia Patrillo, Golden Girls, daughter, home]
# 34907                                            [Tina Turner, singer]
# 35007                                               [meaning, message]
# 35107                                                 [finalist, wife]
# 35207                                                    [hecklephone]
# 35307                                 [stamen, spice, cooking, flower]
# 35407                                                        [capital]
# 35507                                                            [cat]
# 35607                                                 [ant, community]
# 35707                           [honey, stream, minute, blood, period]
# 35807                                       [North Sea, flood, record]
# 35907                                      [judy garland, act, family]
# 36007                                                   [carpal, body]
# 36107                                                     [skin, body]
# 36207                                                               []
# 36307                                                   [final, child]
# 36407                                               [whet, golf, club]
# 36507                                 [Michael Douglas, actress, film]
# 36607                                                  [pronk, animal]
# 36707                             [Hey Can I Try On Your Yellow Dress]
# 36807           [marque, era, aircraft, truck, bus, war, car, company]
# 36907                                  [Star Trek, cartoon, character]
# 37007                                                       [composer]
# 37107     [It takes an awful lot of money to look this cheap., singer]
# 37207                                                        [country]
# 37307                                                [play well, word]
# 37407                                                 [monarch, reign]
# 37507                                              [pop, thing, group]
# 37607                                  [Jonathan Demme, film, picture]
# 37707                                            [gangster, jail, gun]
# 37807  [Thank You For Loving Me, Thank You For Loving Me, song, group]
# 37907                                                           [town]
# 38007                                               [wildlife, island]
# 38107                                  [Valley of the Blue Moon, city]
# 38207                                                       [musician]
# 38307                                               [platoon, officer]
# 38407              [assassination, platinum, attempt, selling, artist]
# 38507                                                          [river]
# 38607                                [Sledgehammer, 1980, singer, hit]
# 38707                                                        [company]
# 38807  [Show Has, Best Of Both Worlds', Best Of Both Worlds, tv, show]
# 38907                                        [producer, album, record]
# 39007                                                         [writer]
# 39107                 [yardbirds, guitarist, generation, career, rock]
# 39207                                                               []
# 39307                                                     [happy days]
# 39407                                                           [kill]
# 39507                                             [Daniel, song, gold]
# 39607                                                        [eyelash]
# 39707            [i will gladly pay you tuesday for a hamburger today]
# 39807                                                    [counterpart]
# 39907                                                    [counterpart]

# %% [markdown]
# # TEST

# %%
text = "Who is the roman counterpart of aphrodite?"

# %%
getObjects(text)
# Out:
# ['aphrodite']
