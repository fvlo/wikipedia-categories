# %%
# ADD
# Batch run functionality
    # Take rows not yet processed, run in batches, save after each batch
# Improve cleaned format of final dataframe (column names and contents)
# Write final category guess rules

# %% [markdown]
# ### Setup

# %%
import pandas as pd
from string import punctuation, digits
import re
import ast
import stopit
from py2neo import *

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 1000)

# %% [markdown]
# #### Keyword to article title mapping data

# %%
# %%time
redirects = pd.read_csv("F:/wikipedia-data/outputs/redirect.csv")
# Out:
# Wall time: 10.3 s

# %%
# %%time
articles = pd.read_csv("F:/wikipedia-data/outputs/articles.csv")
# Out:
# Wall time: 2min 11s

# %%
# %%time
articles.dropna(subset = ["title"], inplace = True)
redirects.dropna(subset = ["title"], inplace = True)
# Out:
# Wall time: 13.3 s

# %%
# %%time
articles["titleLower"] = articles["title"].apply(lambda x: x.lower())
redirects["titleLower"] = redirects["title"].apply(lambda x: x.lower())
# Out:
# Wall time: 5.07 s

# %% [markdown]
# #### Graph database connection

# %%
# Connect to neo4j database - start database separately
graph = Graph()

# %%
# Set timeout-limit in seconds for database calls
maxSearchTime = 45

# %% [markdown]
# #### Trivia data

# %%
# %%time
t_data = pd.read_pickle("../workproduct-files/t_dataMaster-keywordsIdentified.pkl")
# Out:
# Wall time: 714 ms

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Search term to wikipedia article name linking

# %%
#Returns wikipedia article formatted for database search, if not found, returns FALSE
def inArticles(a):
    match = articles.loc[articles["titleLower"] == a.lower(), :]
    if len(match) > 0:
        return match.iloc[0, 1].replace(" ", "_")
    else:
        return False

# %%
#Returns wikipedia article formatted for database search, if not found, returns FALSE
def inRedirects(a):
    match = redirects.loc[redirects["titleLower"] == a.lower(), :]
    if len(match) > 0:
        return match.iloc[0, 2].replace(" ", "_")
    else:
        return False

# %%
#Get first link from article based on title (DB formatting). Return False if no links exist
def getFirstLink(a):
    #match will be a pandas series of len=1
    match = articles.loc[articles["title"] == a.replace("_", " "), "links"]
    
    if len(match) > 0:
        #Change first series value into list
        asList = ast.literal_eval(match.iloc[0]) 
        #result = asList[0].replace(" ", "_")
        result = asList[0]
        
        #Take string only until |
        result = re.sub("(\|)(.+)", '', result)
        result = re.sub("(\|)", '', result)
        
        return result
    else:
        return False

# %% [markdown]
# #### Wikipedia article name to neo4j database calls

# %%
# Call database for category tree and parents of given wikipedia title
@stopit.threading_timeoutable(default='Database call timed out (' + str(maxSearchTime) + ' seconds)')
def getCategoryInfo(a):
    # kill function if runs to long (>2min ?)
        # https://stackoverflow.com/questions/14920384/stop-code-after-time-period
        # https://pypi.org/project/stopit/#id14
    
    #result [wikipediID, path to MTC, parents]
    result = []
    
    try:
        articleID = articleByTitle(a).iloc[0,1]
        parents = parentCategories(articleID)
        
        if "Disambiguation_pages" in parents["pages.title"].values:
            firstLink = getFirstLink(a)
            return getWikipediaInfo(firstLink)
        else:
            path = chosenPathArticleToMTC(articleID)
        
        return [a, articleID, path, parents]
    
    except (IndexError, ValueError, TypeError, ClientError):
        return "Database call not successful (error)"

# %%
# Performs search functions from given search term --> Output from wikipedia database
def getWikipediaInfo(a):
    
    term = a.lower()
    
    out = inArticles(term)
    if out != False:
        return getCategoryInfo(out, timeout = maxSearchTime)
    
    out = inRedirects(term)
    if out != False:
        return getCategoryInfo(out, timeout = maxSearchTime)
    
    return "Search term not found"
        
    
    # if search term is in articles
        # Perform database search
        # Return (WikipediaID, Category tree, Parent categories)
    # else if search term is in redirects
        # Perform database search
        # Return (WikipediaID, Category tree, Parent categories)
    # else return FALSE

# %% [markdown]
# #### neo4j database calls

# %% [markdown]
# ##### Return node info based on wikipedia id

# %%
def nodeInfo(a):
    commandToRun = 'MATCH (pages:Page {id: %s}) \
                RETURN pages' % (a)
    return graph.run(commandToRun).data()

# %% [markdown]
# ##### Return similarity statistics for two sets (intersection, union, Jaccard coefficient)

# %%
# compute similarity statistics
def similarityStats(a,b):
    intSize = len(a.intersection(b))
    unionSize = len(a.union(b))
    
    if unionSize == 0:
        jaccard = 0
    else:
        jaccard = intSize / unionSize
    
    return (intSize, unionSize, jaccard)

# %% [markdown]
# ##### Return identifying information of parent categories of chosen article or category as pandas dataframe

# %%
# Give wikipedia id as integer as function argument (e.g. cateogry "Finland" = 693995)
def parentCategories(a):
    wikiID = a
    commandToRun = 'MATCH (pages:Category:Page) \
                <-[:BELONGS_TO]- \
                (:Page {id: %s}) \
                RETURN pages.title, pages.id' % (wikiID)

    # ensure that a dataframe with correct columns is returnd also when query is empty
    out = pd.DataFrame(columns = ["pages.title", "pages.id"])
    out = out.append(graph.run(commandToRun).to_data_frame())
    
    return out

# %% [markdown]
# ##### Return identifying information of children (both category and article) of chosen category as pandas dataframe

# %%
# Give wikipedia id as integer as function argument (e.g. cateogry "Finland" = 693995)
def childPages(a):
    wikiID = a
    commandToRun = 'MATCH (pages:Page) \
                -[:BELONGS_TO]-> \
                (:Page {id: %s}) \
                RETURN pages.title, pages.id' % (wikiID)

    # ensure that a dataframe with correct columns is returnd also when query is empty
    out = pd.DataFrame(columns = ["pages.title", "pages.id"])
    out = out.append(graph.run(commandToRun).to_data_frame())
    
    return out

# %% [markdown]
# ##### Return dataframe with all articles (but not categories) with given title [only one result is expected]

# %%
# Give wikipedia title as string as function argument
# Will not work if article title contains "-character --> "ClientError". Escape fixes do not work, not worth debugging.
def articleByTitle(a):
    ArticleToFind = a
    commandToRun = 'MATCH (articles:Page {title: "%s"}) \
                    WHERE NONE(art IN [articles] WHERE art:Category) \
                    RETURN articles.title, articles.id, ID(articles)' % (ArticleToFind)
    return graph.run(commandToRun).to_data_frame()

# %% [markdown]
# ##### Return dataframe with all categories (but not articles) with given title [only one result is expected]

# %%
# Give wikipedia title as string as function argument
def categoryByTitle(a):
    CategoryToFind = a
    commandToRun = 'MATCH (categories:Category:Page {title: "%s"}) \
                    RETURN categories.title, categories.id, ID(categories)' % (CategoryToFind)
    return graph.run(commandToRun).to_data_frame()

# %% [markdown]
# ##### Return dataframe containing shortest path between input node (article or category) and Main_topics_classification category

# %%
def shortestPathToMTC(a):
    # (:Page {id: 7345184}) is Main_topics_classifications category node
    inputNode = a

    commandToRun = 'MATCH path=shortestPath( \
                    (:Page {id: %s})-[:BELONGS_TO*0..10]->(:Page {id: 7345184})) \
                    UNWIND nodes(path) AS pages \
                    RETURN pages.title, pages.id, ID(pages)' % (inputNode)

    return pd.DataFrame(graph.run(commandToRun).data())

# %% [markdown]
# ##### Return similarity value between two categories as defined by Biuk-Aghai & Cheang (2011)

# %%
# Take as input tuple containing depth of category to compare to as well as intersection of children between two categories

'''
Given parent category p and child category c,
and given a root category node r, we calculate the category similarity
Sp;c as: Sp;c = Dc - Cp;c / k , where Dc is the depth of category
c in the category graph, i.e. the shortest distance from the root
category node r; Cp;c is the number of co-assigned articles of categories
p and c; and k is a constant that is empirically determined.
Through experimentation we have found that a value of k = 2 produces
the best results, i.e. results that agree with human intuition as
to similarity of a given pair of categories. A smaller value of Sp;c
indicates a greater similarity (i.e. a smaller distance between the
nodes). The number of co-assigned articles Cp;c of parent category
p and child category c is simply the cardinality of the intersection
of their assigned article sets: Cp;c = jAp \ Acj, where Ap and Ac
are the sets of articles assigned to categories p and c, respectively.
'''
# Depth is calcualted for parent when going bottom-up in graph
# C is calculated using intersection of both child articles and sub-categories

def similarityBAC(a):
    d = a[0]
    c = a[1]
    k = 2
    return d - (c/k)

# %% [markdown]
# ##### Return dataframe containing all parent categories of category a and similarity statistics to each as well as parent depth to MTC

# %%
# Give wikipedia id as integer as function argument (e.g. cateogry "Finland" = 693995)
def parentSimilarities(a):
    parents = parentCategories(a)
    children = childPages(a)
    
    if len(parents) == 0:
        raise ValueError("Category processed does not have parents (likely input category to chosenPathUpToMTC() if called)")
    
    # Create columns with similarity stats using functions similarityStats
    parents["similarities"] = parents["pages.id"].apply(lambda x: similarityStats(set(children["pages.id"]), set(childPages(x)["pages.id"])))
    parents[["intersection", "union", "jaccard"]] = pd.DataFrame(parents['similarities'].tolist(), index = parents.index)
    parents.drop(["similarities"], axis = 1, inplace = True)
        
    # Add column with parent category depth (steps to Main_topics_classifications node)
    parents["depth"] = parents["pages.id"].apply(lambda x: len(shortestPathToMTC(x))-1)
    
    # Add column with similarityBAC
    parents["similarityBAC-aid"] = list(zip(parents["depth"], parents["intersection"]))
    parents["similarityBAC"] = parents["similarityBAC-aid"].apply(lambda x: similarityBAC(x))
    parents.drop(["similarityBAC-aid"], axis = 1, inplace = True)
    
    # Sort ascending
    parents.sort_values(by = "similarityBAC", ascending = True, inplace = True)
    parents.reset_index(drop = True, inplace = True)
    
    return parents

# %% [markdown]
# ##### Return node based on neo4j database ID [NOTE: not same as wikipedia ID used elsewhere]

# %%
def getWithNeoID(a):
    return NodeMatcher(graph).get(a)

# %% [markdown]
# ##### Return dataframe containing info of what category to choose from parentSimilarities() output

# %%
'''
we choose which parent link to keep according to
following rules: (1) Choose the parent whose similarity value Sp;c
is lower; (2) If Sp1;c = Sp2;c, choose the parent whose depth D is
lower; (3) If Dp1 = Dp2, choose the parent with the larger value
of Cp;c; (4) If Cp1;c = Cp2;c, choose the parent with the lower
page ID.
'''
# Takes parentSimilarities() / or potentially child similarities output dataframe as input
def chooseCategoryPath(a):
    a.sort_values(by = ["similarityBAC", "depth"], ascending = True, inplace = True)
    a["mostSimilar"] = "False"
    a["comment"] = ""
    
    # Set value for mostSimilar to "Not connected" for rows with depth = -1 i.e. no connection to MTC
    a.loc[a["depth"] == -1, "comment"] = "Not connected"
    
    # Set value for mostSimilar to "True" for rows that are not "Not connected" and that have the minimum value of similarityBAC
    workingDF = a.loc[a["comment"] != "Not connected"]
    selectedIndexes = workingDF.loc[workingDF["similarityBAC"] == workingDF["similarityBAC"].min()].index
    
    a.loc[selectedIndexes, "mostSimilar"] = "True"
    a.loc[selectedIndexes, "comment"] = "Lowest similarityBAC"
    
    workingDF = a.loc[a["mostSimilar"] == "True"]
    
    if len(workingDF) > 1:
        # Set all mostSimilar of partial dataframe and output back to False, then set min depth rows to true
        workingDF["mostSimilar"] = "False"
        a["mostSimilar"] = "False"
        selectedIndexes = workingDF.loc[workingDF["depth"] == workingDF["depth"].min()].index
        
        a.loc[selectedIndexes, "mostSimilar"] = "True"
        a.loc[selectedIndexes, "comment"] = a.loc[selectedIndexes, "comment"] + "; Lowest depth"
        
        workingDF = a.loc[a["mostSimilar"] == "True"]
        
        # If several rows now set to true, test for highest intersection
        if len(workingDF) > 1:
            # Set all mostSimilar of partial dataframe and output back to False, then set max intersection rows to true
            workingDF["mostSimilar"] = "False"
            a["mostSimilar"] = "False"
            selectedIndexes = workingDF.loc[workingDF["intersection"] == workingDF["intersection"].max()].index
            
            a.loc[selectedIndexes, "mostSimilar"] = "True"
            a.loc[selectedIndexes, "comment"] = a.loc[selectedIndexes, "comment"] + "; Highest intersection"
            
            workingDF = a.loc[a["mostSimilar"] == "True"]
            
            # If several rows now set to true, choose row with lowes pages.id
            if len(workingDF) > 1:
                # Set all mostSimilar of partial dataframe and output back to False, then set min wikipedia id row (only one) to true
                workingDF["mostSimilar"] = "False"
                a["mostSimilar"] = "False"
                selectedIndexes = workingDF.loc[workingDF["pages.id"] == workingDF["pages.id"].min()].index
                
                a.loc[selectedIndexes, "mostSimilar"] = "True"
                a.loc[selectedIndexes, "comment"] = a.loc[selectedIndexes, "comment"] + "; Lowest wikipedia id"
    
    
    return a

# %% [markdown]
# ##### Return dataframe containing info of chosen path to MTC (iterates chooseCategoryPath() upwards)

# %%
# Iterate chooseCategoryPath() from input category (wikipedia id as input) until MTC is reached. Return dataframe with chosen path rows
# Root node category "Main_topic_classifications" has pages.id = 7345184

# NOTE: Error if input category does not have parents
def chosenPathUpToMTC(a):
    mtcFound = False
    nextStep = a
    chosenPath = pd.DataFrame()
    
    while(not mtcFound):
        allParents = parentSimilarities(nextStep)
        allParents = chooseCategoryPath(allParents)
        
        # If allParents contains MTC category
        if(len(allParents.loc[allParents["pages.id"] == 7345184]) == 1):
            rowToAppend = allParents.loc[allParents["pages.id"] == 7345184]
            mtcFound = True
        else:
            rowToAppend = allParents.loc[allParents["mostSimilar"] == "True"]
            nextStep = int(allParents.loc[allParents["mostSimilar"] == "True", "pages.id"])
        
        chosenPath = chosenPath.append(rowToAppend)
        chosenPath.reset_index(drop = True, inplace = True)
    
    
    return chosenPath

# %% [markdown]
# ##### Article strength calculations

# %%
# Return dataframe with all pages linking to or from input page
def linksBetween(a):
    wikiID = a
    commandToRun = 'MATCH (pages:Page) \
                -[:LINKS_TO]- \
                (:Page {id: %s}) \
                RETURN pages.title, pages.id' % (wikiID)

    # ensure that a dataframe with correct columns is returnd also when query is empty
    out = pd.DataFrame(columns = ["pages.title", "pages.id"])
    out = out.append(graph.run(commandToRun).to_data_frame())
    
    return out

# %%
# a as pages.id for artice, c as pages.id for parent category
def articleClassificationStrength(a, c):
    aLinks = set(linksBetween(a)["pages.id"])
    cChildren = set(childPages(c)["pages.id"])
    
    intersectionSize = len(aLinks.intersection(cChildren))
    
    return 1 + intersectionSize

# %%
def strongestArticleParents(a):
    parents = parentCategories(a)
    parents["depth"] = parents["pages.id"].apply(lambda x: len(shortestPathToMTC(x)) -1 )
    parents.loc[parents["depth"] != -1 , "Strength"] = parents["pages.id"].apply(lambda x: articleClassificationStrength(a, x))
    parents.sort_values(by = ["Strength"], ascending = False, inplace = True)
   
    
    return parents

# %%
def chosenPathArticleToMTC(a):
    strongestParent = strongestArticleParents(a)
    path = chosenPathUpToMTC(strongestParent.iloc[0,1])
    
    path.loc[-1] = strongestParent.iloc[0, :3]
    path.sort_index(inplace = True)
    path.reset_index(drop = True, inplace = True)
    
    return path

# %% [markdown]
# # Test - Run "question to wikipedia category" analyses

# %%
# Fix functionality in findQuestionCategories
    # Save error messages
# Write batch processing

# %%
# Take list with search terms
# Run getWikipediaInfo() until search term works
# If result is False (search term not found) or "Database call not successful (error)" (search term found but path to MTC not available)
    # --> continue to next search term
# Return [search term used, result]

def findQuestionCategories(a):
    result = []
    for term in a:
        termResult = getWikipediaInfo(term)
        possibleFailureMessages = ('Search term not found', 'Database call timed out (' + str(maxSearchTime) + ' seconds)', 'Database call not successful (error)')
        
        result.append((term, termResult))
        if termResult not in possibleFailureMessages:
            break
    
    if len(result) == 0:
        result.append(("NO SEARCH TERMS GIVEN"))
            
    return result

# %%
# %%time
a = findQuestionCategories(["aslökdfhjaölskjdhf", "sanna marin", "Ben Hur"])
# Out:
# Wall time: 50.7 s

# %%
a[-1][1]
# Out:
# ['Ben-Hur:_A_Tale_of_the_Christ',
#  1343296,
#                    pages.title  pages.id  intersection  union  jaccard  depth  \
#  0                     Ben-Hur  45418958           NaN    NaN      NaN      3
#  1            Media_franchises   1170420           0.0  706.0      0.0      2
#  2               Entertainment    693016           0.0  826.0      0.0      1
#  3  Main_topic_classifications   7345184           0.0  148.0      0.0      0
#
#     similarityBAC mostSimilar               comment
#  0            NaN         NaN                   NaN
#  1            2.0        True  Lowest similarityBAC
#  2            1.0        True  Lowest similarityBAC
#  3            0.0       False                        ,
#                                                      pages.title  pages.id
#  0                                       Harper_&_Brothers_books  37833610
#  1                            American_novels_adapted_into_films  28078409
#  2              Pages_using_citations_with_accessdate_and_no_URL  38916880
#  3                             CS1:_Julian–Gregorian_uncertainty  56612665
#  4                                          Novels_about_slavery  33580926
#  5                                                       Ben-Hur  45418958
#  6                 Cultural_depictions_of_Mary_(mother_of_Jesus)  49052969
#  7                                Novelistic_portrayals_of_Jesus  14783406
#  8                                     American_Christian_novels  28111293
#  9   Commons_category_with_local_link_different_than_on_Wikidata  39217578
#  10                           American_novels_adapted_into_plays  51476220
#  11                        Cultural_depictions_of_Pontius_Pilate  56582449
#  12                            CS1_maint:_Uses_authors_parameter  51203086]

# %%
# Split successful search from non-succesfull (two columns)
# Split successful into separate columns (search term, article title, articleID, path, parents)

# %%
def explodeCatData(a, b):
    if len(a) >= b+1:
        return a[b]

# %%
use = t_data.iloc[9::600]

# %%
len(use)
# Out:
# 108

# %%
# %%time
# Run time for 7 rows: 38,2 seconds
# Run time for 65 rows: 7min 31s
# Run time for 108 rows: 13min 49s
use["wikipediaOutput"] = use["searchTerms"].apply(lambda x: findQuestionCategories(x))
# Out:
# <ipython-input-25-0b2f5f3b6b43>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   workingDF["mostSimilar"] = "False"
# <ipython-input-25-0b2f5f3b6b43>:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   workingDF["mostSimilar"] = "False"
# <ipython-input-25-0b2f5f3b6b43>:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   workingDF["mostSimilar"] = "False"
# Wall time: 13min 49s
# <timed exec>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
use["searchTermUsed"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 0))
use["wikipediaArticleTitle"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 1))
use["wikipediaArticleID"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 2))
use["wikipediaCategoryInfo"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 3))
# Out:
# <ipython-input-45-0afe29a46763>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use["searchTermUsed"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 0))
# <ipython-input-45-0afe29a46763>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use["wikipediaArticleTitle"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 1))
# <ipython-input-45-0afe29a46763>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use["wikipediaArticleID"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 2))
# <ipython-input-45-0afe29a46763>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use["wikipediaCategoryInfo"] = use["wikipediaOutput"].apply(lambda x: explodeCatData(x, 3))

# %%
use["nextToMtcCategory"] = use["wikipediaCategoryInfo"].apply(lambda x: x.iloc[-2,0] if x is not None else None)
# Out:
# <ipython-input-46-46ce416da925>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   use["impliedCategory"] = use["wikipediaCategoryInfo"].apply(lambda x: x.iloc[-2,0] if x is not None else None)

# %%
use.drop(columns=["wikipediaOutput"], inplace = True)
# Out:
# C:\Users\Fredi\miniconda3\envs\data-analysis\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
use.to_pickle("../workproduct-files/TEST-categorySearch.pkl")

# %%
use.columns
# Out:
# Index(['CONS_id', 'CONS_question', 'CONS_answer', 'CONS_alt answers',
#        'CONS_category', 'CONS_alt categories - NOT USED',
#        'CONS_type-formulation', 'CONS_type-multipleChoice', 'ORIG_id',
#        'ORIG_question', 'ORIG_answer', 'ORIG_alt answers', 'ORIG_category',
#        'ORIG_alt categories', 'ORIG_difficulty', 'ORIG_type', 'Source',
#        'Duplicate_removed', 'namedEntities', 'nouns', 'searchTerms',
#        'searchTermUsed', 'wikipediaArticleTitle', 'wikipediaArticleID',
#        'wikipediaCategoryInfo', 'impliedCategory'],
#       dtype='object')

# %%
#use.loc[:, ["CONS_question", "CONS_answer", "CONS_category", "impliedCategory"]]
use.loc[:,["CONS_question", "CONS_answer", "CONS_category", "impliedCategory", 'namedEntities', "searchTerms", 'searchTermUsed', 'wikipediaCategoryInfo']]
# Out:
#                                                                                                                                                                                   CONS_question  \
# 9                                                                         A European style developed in France in the late eleventh century. Its sculpture is ornamental, stylized and complex.
# 609                                                                                          In this 1968 film the husband of an unsuspecting young wife becomes involved with a witch's coven.
# 1209                                                                                                                                                Who's first release was 'Talking Heads 77'?
# 1809                                                                                                                                                          What Is The Most Expensive Spice?
# 2409                                                                                                                                                  In which ocean or sea are the Seychelles?
# 3009                                                                                                                                       What is the basic unit of currency for Saudi Arabia?
# 3609                                                                                                                                         Which element makes up 2.83% of the earth's crust?
# 4209                                                                                               In which 1947 Christmas film do a lovestruck couple pretend that the snowman is Parson Brow?
# 4809                                                                                                                                                          What type of animal is a caribou?
# 5409                                                                                                                 Who Described Russia As (A Riddle Wrapped In A Mystery, Inside An Enigma)?
# 6009                                                                                                                                   According To The Beatles Who has "hair of floating sky"?
# 6609                                                                                                                                         Mick Hucknall Is The Lead Singer With Which Group?
# 7209                                                                                                                                                What Is The Name Of Michael Jacksons Ranch?
# 7809                                                                                                             Which Country Singer Guested With The KLF On Their Single Justified & Ancient?
# 8409                                                                                                                                    Who Fell To His Death From An Amsterdam Window In 1988?
# 9009                                                                                                                             Who were the only band to play at Both Woodstock and Live Aid?
# 9609                                                                                                                                        Who is the greek equivalent of the roman god vesta?
# 10209  Many seabirds that swallow fishes too large for immediate digestion go about with the esophagus filled. Apparently without discomfort, the tail of the fish sticks out of the __________
# 10809                                                                                                                               What Disorder Is Characterised By Appetite And Weight Loss?
# 11409                                                                                                                                                   What Vaccine Did Edward Jenner Develop?
# 12009                                                                                                                                           How Many Jumps Are There In The Grand National?
# 12609                                                                                                                                                        Where were the 1960 Olympics held?
# 13209                                                                                                                           How many tiles does a player play to score a bingo in Scrabble?
# 13809                                                                                                                                                     A Librocuricularist does what in bed?
# 14409                                                                                                                                                           All living things contain what?
# 15009                                                                                                                                                Bangalore and Jaipur are in which country?
# 15609                                                                                                                               Charcarodon Carcharias is the Latin name for what creature?
# 16209                                                                                                                              Dr Seuss created the first animated TV ad for which company?
# 16809                                                                                                                            Frodo. Gandalf and Bilbo Baggins are all characters from what?
# 17409                                                                                                                             How does the mermaid buy the gift for tom hanks in 'splash''?
# 18009                                                                                                                              If you went on the road to Mandalay what country are you in?
# 18609                                                                                                                         In California 22 ' is the minimum legal length of saleable what'?
# 19209                                                                                                                                      In mythology who married the beautiful maid Galatea?
# 19809                                                                                                                        In the tv series 'leave it to beaver', what was the mother's name?
# 20409                                                                                                               In which country are Cape Otway, Mount Gambier, and the Grampian Mountains?
# 21009                                                                                                                                                   Ixchel is the mayan patroness of ______
# 21609                                                                                                                                       Margaret Thatcher day is 10th January in what area?
# 22209                                                                                                                  Name the only major Greek God whose Roman counterpart has the same name?
# 22809                                                                                                                                       On which river does St. Petersburg in Russia stand?
# 23409                                                                                                                                  Ranch what famous building did sir john vanbrugh design?
# 24009                                                                                                                                          Spell the name of the largest city in new mexico
# 24609                                                                                    The duodenum and the jejunum are two of the three sections of the small intestine. Which is the third?
# 25209                                                                                                                            The President of Gabon banned the use of what word in country?
# 25809                                                                                                                                This Toy is based on a Filipino Hunters Weapon what is it?
# 26409                                                                                                                             What 1969 sex spoof had a different author for every chapter?
# 27009                                                                                                                          What broadway musical was inspired by cervantes's 'don quixote'?
# 27609                                                                                                                                                                    What date was V E day?
# 28209                                                                                                                                                                 What does AIDS stand for?
# 28809                                                                                                                                             What grape variety is used to make champagne?
# 29409                                                                                                                                                             What is a group of wild dogs?
# 30009                                                                                                                                         What is ornamental work in silver or gold thread?
# 30609                                                                                                                                                     What is the fear of leprosy known as?
# 31209                                                                                                                                              What is the main constituent of natural gas?
# 31809                                                                                                                                What is the only metal that is liquid at room temperature?
# 32409                                                                                                                                      What killed 23 people in Rostov Russia in July 1923?
# 33009                                                                                                                     What novel by Geoffrey Household was about an attempt to kill Hitler?
# 33609                                                                                                                                                  What spice comes from the curcuma plant?
# 34209                                                                                                                                     What was Bogart's full characters name in Casablanca?
# 34809                                                                                                                                            What was the name of the horse in Animal Farm?
# 35409                                                                                                                                         What's the capital of the central african empire?
# 36009                                                                                                                                    Where in the body would you find your olfactory lobes?
# 36609                                                                                                                                                          Which animal sleeps on its back?
# 37209                                                                                                                                 Which country made the worlds first feature film in 1906?
# 37809                                                                                                                                                   Which group sang the song 'Unforgiven'?
# 38409                                                                                                                                       Which playing card is called the Curse of Scotland?
# 39009                                                                                                                            Which writer created Tabitha Twitchet, Babbity Bumble, Mr Tod?
# 39609                                                                                                                                                                  Who invented Lava Lamps?
# 40209                                                                                                                                           Who played Sarah Connor in 1984's 'Terminator'?
# 40809                                                                                                                 Who was British Prime Minister at the time of the General Strike in 1926?
# 41409                                                                                                                                            Who was the oldest man to hold a boxing title?
# 42009                                                                                                                                      Who, at USA customs declared, nothing but my genius?
# 42609                                                                                                              What is the name of Finnish DJ Darude's hit single released in October 1999?
# 43209                                                                                                                                  Ferrari has never made a V10 engine for any of its cars.
# 43809                                                                                                          What Queen song plays during the final fight scene of the film "Hardcore Henry"?
# 44409                                                                                                                                        Which Batman sidekick is the son of Talia al Ghul?
# 45009                                                                                                                                    Who starred in the film 1973 movie "Enter The Dragon"?
# 45609                                                                                                             What was the name of the hero in the 80s animated video game 'Dragon's Lair'?
# 46209                                                                                                                                              What is the first book of the old testament?
# 46809                                                                                                                                                        What is the Spanish word for meat?
# 47409                                                                                                                                           Approximately, how many seconds comprise a day?
# 48009                                                                                                                          What was the name of Hewlett-Packard's first successful product?
# 48609                                                                                                                                    Who is Mufasa's son in Disney's movie "The Lion King"?
# 49209                                                                                                                             What color M&M was retired to make way for blue M&Ms in 1995?
# 49809                                                                            Whose "Coffee Cantata" concerns a girl whose father demands she loses her addiction to coffee before marriage?
# 50409                                                                                                                                                      Who wielded a sword named excalibur?
# 51009                                                                                                                                      Who was the first African American mayor of Chicago?
# 51609                                                                                                                                                              Who was known as "The King"?
# 52209                                                                                                                         What state is the oldest US commercial pretzel bakery located in?
# 52809                                                                                                                                                       What percent of jellyfish is water?
# 53409                                                                                                    What is the name of the ranch the Cartwright family operates in the TV show "Bonanza"?
# 54009                                                                                                                                                   What does "vermicelli" mean in Italian?
# 54609                                                                                                    What fraternity do the Lewis and Gilbert join in the 1984 film "Revenge of the Nerds"?
# 55209                                                                                                                                 What is the only officially bilingual province in Canada?
# 55809                                                                                                                  In what film does Gene Hackman play the sheriff of Big Whiskey, Wyoming?
# 56409                                                                                                                             What do you call an animal that eats both plants and animals?
# 57009                                                                                                                          Which publication serialized the 1897 novel "The Invisible Man"?
# 57609                                                                                                                                     Who directed and acted in the movie "Reservoir Dogs"?
# 58209                                                                                                                          What English party was politician Arthur Hayday associated with?
# 58809                                                                                                                                  What is Philo T. Farnsworth credited with for inventing?
# 59409                                                                                                                                       "Confide in Me" was a hit in 1994 for which singer?
# 60009                                                                                                                                    What two countries share land borders with Bangladesh?
# 60609                                                                                                                                   What jazz singer was the U2 song Angel of Harlem about?
# 61209                                                                                                                                                      In what year was DNA first isolated?
# 61809                                                                                                                  What citrus beverage has used the ad slogan "Open a Bottle of Sunshine"?
# 62409                                                                                                                                                        How many candles are on a menorah?
# 63009                                                                                                                        What country had, at one time, a female "Santa" called Babouschka?
# 63609                                                                                                                    Clams and snails are part of what phylum or biological classification?
# 64209                                                                                                          Prior to the early 1980’s, the Japanese automaker Nissan was known by what name?
#
#                                CONS_answer         CONS_category  \
# 9                               Romanesque    Art and literature
# 609                        Rosemary's Baby         Entertainment
# 1209                         Psycho Killer         Entertainment
# 1809                               Saffron    Sports and leisure
# 2409                          Indian Ocean  Geography and places
# 3009                                 Riyal  Geography and places
# 3609                                Sodium  Geography and places
# 4209                     Winter Wonderland   History and society
# 4809                            A Reindeer   History and society
# 5409                     Winston Churchill   History and society
# 6009                                 Julia         Entertainment
# 6609                            Simply Red         Entertainment
# 7209                             Neverland         Entertainment
# 7809                         Tammy Wynette         Entertainment
# 8409                            Chet Baker         Entertainment
# 9009                               The Who         Entertainment
# 9609                                Hestia    Art and literature
# 10209                         Bird's mouth    Science and nature
# 10809                     Anorexia Nervosa    Science and nature
# 11409                 The Smallpox Vaccine    Science and nature
# 12009                             30 Jumps    Sports and leisure
# 12609                          Rome, Italy    Sports and leisure
# 13209                                    7         Entertainment
# 13809                                 Read         Uncategorized
# 14409                                Water         Uncategorized
# 15009                                India         Uncategorized
# 15609                    Great White Shark         Uncategorized
# 16209                                 Ford         Uncategorized
# 16809                The lord of the rings         Uncategorized
# 17409                         Her necklace         Uncategorized
# 18009                     Miramar or Burma         Uncategorized
# 18609                              Halibut         Uncategorized
# 19209        King Pygmalion Aphrodite life         Uncategorized
# 19809                                 June         Uncategorized
# 20409                            Australia         Uncategorized
# 21009                       Pregnant women         Uncategorized
# 21609                    Falklands Islands         Uncategorized
# 22209                               Apollo         Uncategorized
# 22809                                 Neva         Uncategorized
# 23409                      Blenheim palace         Uncategorized
# 24009                          Albuquerque         Uncategorized
# 24609                                Ileum         Uncategorized
# 25209                                Pygmy         Uncategorized
# 25809                                Yo Yo         Uncategorized
# 26409                       Naked came the         Uncategorized
# 27009                            Man of la         Uncategorized
# 27609                           May 8 1945         Uncategorized
# 28209  Acquired immune deficiency syndrome         Uncategorized
# 28809                           Chardonnay         Uncategorized
# 29409                                 Pack         Uncategorized
# 30009                             Filigree         Uncategorized
# 30609                          Leprophobia         Uncategorized
# 31209                              Methane         Uncategorized
# 31809                              Mercury    Science and nature
# 32409                     Giant Hailstones         Uncategorized
# 33009                           Rogue male    Art and literature
# 33609                             Turmeric         Uncategorized
# 34209                           Rick Blain         Uncategorized
# 34809                                Boxer         Uncategorized
# 35409                               Bangui         Uncategorized
# 36009                                 Nose         Uncategorized
# 36609                    Only man or women         Uncategorized
# 37209        Australia Story of Kelly gang         Uncategorized
# 37809                            Metallica         Uncategorized
# 38409                     Nine of Diamonds         Uncategorized
# 39009                       Beatrix Potter         Uncategorized
# 39609                        Craven Walker         Uncategorized
# 40209                       Linda Hamilton         Uncategorized
# 40809                      Stanley baldwin         Uncategorized
# 41409                         Archie moore         Uncategorized
# 42009                          Oscar Wilde         Uncategorized
# 42609                            Sandstorm         Entertainment
# 43209                                False    Sports and leisure
# 43809                    Don't Stop Me Now         Entertainment
# 44409                         Damian Wayne         Entertainment
# 45009                            Bruce Lee         Entertainment
# 45609                      Dirk the Daring         Entertainment
# 46209                              Genesis         Uncategorized
# 46809                                Carne   History and society
# 47409                                86400         Uncategorized
# 48009                               HP200A   History and society
# 48609                                Simba         Entertainment
# 49209                                  Tan         Uncategorized
# 49809              Johann Sebastian Bach's    Art and literature
# 50409                          King Arthur    Art and literature
# 51009                    Harold Washington   History and society
# 51609                        Elvis Presley         Entertainment
# 52209                         Pennsylvania         Uncategorized
# 52809                                  95%    Science and nature
# 53409                      Ponderosa Ranch         Entertainment
# 54009                         Little worms         Uncategorized
# 54609                 Lambda Lambda Lambda         Entertainment
# 55209                        New Brunswick  Geography and places
# 55809                           Unforgiven         Entertainment
# 56409                          An Omnivore    Science and nature
# 57009                     Pearson's Weekly    Art and literature
# 57609                    Quentin Tarantino         Entertainment
# 58209                         Labour Party   History and society
# 58809                           Television    Science and nature
# 59409                        Kylie Minogue         Entertainment
# 60009                    India and Myanmar  Geography and places
# 60609                       Billie Holiday         Entertainment
# 61209                                 1869    Science and nature
# 61809                        Sunny Delight         Uncategorized
# 62409                                    9         Uncategorized
# 63009                               Russia         Uncategorized
# 63609                             Mollusks    Science and nature
# 64209                               Datsun         Uncategorized
#
#               impliedCategory  \
# 9                        Arts
# 609                  Religion
# 1209                     None
# 1809                     None
# 2409                   Nature
# 3009                  Society
# 3609                   Nature
# 4209               Humanities
# 4809                   Nature
# 5409            Entertainment
# 6009                     None
# 6609            Entertainment
# 7209                     None
# 7809            Entertainment
# 8409                     Life
# 9009                 Politics
# 9609            Entertainment
# 10209                    Life
# 10809                 History
# 11409                  Health
# 12009                  Nature
# 12609                    None
# 13209                Language
# 13809                  Health
# 14409              Philosophy
# 15009               Geography
# 15609                    None
# 16209           Entertainment
# 16809           Entertainment
# 17409           Entertainment
# 18009                 Culture
# 18609                    None
# 19209              Humanities
# 19809                    Arts
# 20409               Geography
# 21009                Language
# 21609                Politics
# 22209              Humanities
# 22809                    None
# 23409                    Arts
# 24009               Geography
# 24609                  Health
# 25209                Language
# 25809                    None
# 26409                 Society
# 27009           Entertainment
# 27609                Language
# 28209                    None
# 28809                  Health
# 29409              Humanities
# 30009                  Nature
# 30609                Language
# 31209               Geography
# 31809                  Nature
# 32409              Humanities
# 33009           Entertainment
# 33609               Geography
# 34209           Entertainment
# 34809              Humanities
# 35409                 History
# 36009              Humanities
# 36609                    None
# 37209           Entertainment
# 37809           Entertainment
# 38409              Humanities
# 39009                Language
# 39609                 Culture
# 40209                    Life
# 40809             Mathematics
# 41409                  Sports
# 42009               Education
# 42609                    None
# 43209  Science_and_technology
# 43809           Entertainment
# 44409              Humanities
# 45009           Entertainment
# 45609              Humanities
# 46209                     Law
# 46809                  Health
# 47409             Mathematics
# 48009                 Society
# 48609           Entertainment
# 49209                  Nature
# 49809           Entertainment
# 50409                  Health
# 51009                Politics
# 51609                Language
# 52209                  Health
# 52809                    Life
# 53409                    Arts
# 54009                  Health
# 54609           Entertainment
# 55209               Geography
# 55809           Entertainment
# 56409                    None
# 57009              Humanities
# 57609           Entertainment
# 58209                 Society
# 58809                 History
# 59409           Entertainment
# 60009               Geography
# 60609              Humanities
# 61209                    Life
# 61809                    Arts
# 62409                Religion
# 63009              Humanities
# 63609                    Life
# 64209                 Society
#
#                                                                                    namedEntities  \
# 9                           [(European, NORP), (France, GPE), (the late eleventh century, DATE)]
# 609                                                                               [(1968, DATE)]
# 1209                                                                          [(first, ORDINAL)]
# 1809                                                                                          []
# 2409                                                                                          []
# 3009                                                                       [(Saudi Arabia, GPE)]
# 3609                                                            [(2.83%, PERCENT), (earth, LOC)]
# 4209                                    [(1947, DATE), (Christmas, DATE), (Parson Brow, PERSON)]
# 4809                                                                                          []
# 5409                                                          [(Russia, GPE), (Enigma, PRODUCT)]
# 6009                                                                                          []
# 6609                  [(Mick Hucknall, PERSON), (The Lead Singer With Which Group, WORK_OF_ART)]
# 7209                                                                                          []
# 7809                                                                                          []
# 8409                                                                              [(1988, DATE)]
# 9009                                                        [(Both Woodstock and Live Aid, ORG)]
# 9609                                                                             [(greek, NORP)]
# 10209                                                                                         []
# 10809                                                                       [(Disorder, PERSON)]
# 11409                                                                                         []
# 12009                                                                                         []
# 12609                                                               [(the 1960 Olympics, EVENT)]
# 13209                                                                          [(Scrabble, LOC)]
# 13809                                                                                         []
# 14409                                                                                         []
# 15009                                                                            [(Jaipur, ORG)]
# 15609                                          [(Charcarodon Carcharias, PERSON), (Latin, NORP)]
# 16209                                                        [(Seuss, PERSON), (first, ORDINAL)]
# 16809                                                                  [(Bilbo Baggins, PERSON)]
# 17409                                                                      [(tom hanks, PERSON)]
# 18009                                                                                         []
# 18609                                                                        [(California, GPE)]
# 19209                                                                                         []
# 19809                                                                                         []
# 20409                   [(Cape Otway, GPE), (Mount Gambier, LOC), (the Grampian Mountains, LOC)]
# 21009                                                             [(Ixchel, ORG), (mayan, NORP)]
# 21609                            [(Margaret Thatcher, PERSON), (10th, ORDINAL), (January, DATE)]
# 22209                                                             [(Greek, NORP), (Roman, NORP)]
# 22809                                                     [(St. Petersburg, GPE), (Russia, GPE)]
# 23409                                                                  [(john vanbrugh, PERSON)]
# 24009                                                                                         []
# 24609                                     [(two, CARDINAL), (three, CARDINAL), (third, ORDINAL)]
# 25209                                                                                         []
# 25809                                                             [(Toy, ORG), (Filipino, NORP)]
# 26409                                                                             [(1969, DATE)]
# 27009                        [(broadway, FAC), (cervantes, PERSON), (don quixote', WORK_OF_ART)]
# 27609                                                                                         []
# 28209                                                                                         []
# 28809                                                                                         []
# 29409                                                                                         []
# 30009                                                                                         []
# 30609                                                                                         []
# 31209                                                                                         []
# 31809                                                                                         []
# 32409                                  [(23, CARDINAL), (Rostov Russia, GPE), (July 1923, DATE)]
# 33009                                           [(Geoffrey Household, PERSON), (Hitler, PERSON)]
# 33609                                                                                         []
# 34209                                                      [(Bogart, PERSON), (Casablanca, GPE)]
# 34809                                                                       [(Animal Farm, ORG)]
# 35409                                                                                         []
# 36009                                                                                         []
# 36609                                                                                         []
# 37209                                                           [(first, ORDINAL), (1906, DATE)]
# 37809                                                                [(Unforgiven, WORK_OF_ART)]
# 38409                                                                          [(Scotland, GPE)]
# 39009                   [(Tabitha Twitchet, PERSON), (Babbity Bumble, PERSON), (Mr Tod, PERSON)]
# 39609                                                                     [(Lava Lamps, PERSON)]
# 40209                         [(Sarah Connor, PERSON), (1984, DATE), (Terminator', WORK_OF_ART)]
# 40809                             [(British, NORP), (the General Strike, PRODUCT), (1926, DATE)]
# 41409                                                                                         []
# 42009                                                                               [(USA, GPE)]
# 42609                             [(Finnish, NORP), (DJ Darude's, PERSON), (October 1999, DATE)]
# 43209                                                               [(Ferrari, ORG), (V10, ORG)]
# 43809                                         [(Queen, PERSON), ("Hardcore Henry", WORK_OF_ART)]
# 44409                                                     [(Batman, NORP), (Talia al Ghul, ORG)]
# 45009                                          [(1973, DATE), ("Enter The Dragon", WORK_OF_ART)]
# 45609                                                       [(80s, DATE), (Dragon's Lair', ORG)]
# 46209                                                                         [(first, ORDINAL)]
# 46809                                                                          [(Spanish, NORP)]
# 47409                                                                          [(seconds, TIME)]
# 48009                                               [(Hewlett-Packard's, ORG), (first, ORDINAL)]
# 48609                            [(Mufasa, PERSON), (Disney, ORG), (The Lion King, WORK_OF_ART)]
# 49209                                                                 [(M&M, ORG), (1995, DATE)]
# 49809                                                                                         []
# 50409                                                                         [(excalibur, ORG)]
# 51009                               [(first, ORDINAL), (African American, NORP), (Chicago, GPE)]
# 51609                                                                  [(The King, WORK_OF_ART)]
# 52209                                                                                [(US, GPE)]
# 52809                                                                                         []
# 53409                                             [(Cartwright, PERSON), (Bonanza, WORK_OF_ART)]
# 54009                                                                          [(Italian, NORP)]
# 54609  [(Lewis, PERSON), (Gilbert, PERSON), (1984, DATE), ("Revenge of the Nerds", WORK_OF_ART)]
# 55209                                                                            [(Canada, GPE)]
# 55809                                                   [(Gene Hackman, PERSON), (Wyoming, GPE)]
# 56409                                                                                         []
# 57009                                           [(1897, DATE), (The Invisible Man, WORK_OF_ART)]
# 57609                                                            [(Reservoir Dogs, WORK_OF_ART)]
# 58209                                                 [(English, NORP), (Arthur Hayday, PERSON)]
# 58809                                                            [(Philo T. Farnsworth, PERSON)]
# 59409                                               [(Confide in Me, WORK_OF_ART), (1994, DATE)]
# 60009                                                       [(two, CARDINAL), (Bangladesh, ORG)]
# 60609                                                                   [(Angel of Harlem, FAC)]
# 61209                                                                        [(what year, DATE)]
# 61809                                                 [(Open a Bottle of Sunshine, WORK_OF_ART)]
# 62409                                                                                         []
# 63009                                 [(one, CARDINAL), (Santa, WORK_OF_ART), (Babouschka, ORG)]
# 63609                                                                                         []
# 64209                                            [(1980, DATE), (Japanese, NORP), (Nissan, ORG)]
#
#                                                                                 searchTerms  \
# 9                                                      [sculpture, complex, century, style]
# 609                                                     [coven, witch, husband, wife, film]
# 1209                                                                 [s first release was ]
# 1809                                                                                [spice]
# 2409                                                                           [ocean, sea]
# 3009                                                                       [currency, unit]
# 3609                                                         [earth, crust, element, earth]
# 4209                                          [Parson Brow, snowman, pretend, couple, film]
# 4809                                                                [caribou, animal, type]
# 5409                                                              [enigma, riddle, mystery]
# 6009                                                                 [hair of floating sky]
# 6609           [Lead Singer With Which Group, Mick Hucknall, hucknall, singer, lead, group]
# 7209                                                                                     []
# 7809                                                                 [klf, singer, country]
# 8409                                                                        [death, window]
# 9009                                                                            [aid, band]
# 9609                                                                           [equivalent]
# 10209               [seabird, esophagus, digestion, discomfort, swallow, tail, stick, fish]
# 10809                                          [Disorder, appetite, disorder, loss, weight]
# 11409                                                                             [vaccine]
# 12009                                                                                [jump]
# 12609                                                                                    []
# 13209                                                       [Scrabble, tile, bingo, player]
# 13809                                                              [librocuricularist, bed]
# 14409                                                                               [thing]
# 15009                                                                             [country]
# 15609                                                    [Charcarodon Carcharias, creature]
# 16209                                                              [Seuss, ad, tv, company]
# 16809                                                            [Bilbo Baggins, character]
# 17409                                                    [tom hanks, mermaid, splash, gift]
# 18009                                                                       [road, country]
# 18609                                       [ is the minimum legal length of saleable what]
# 19209                                                                     [mythology, maid]
# 19809                                              [leave it to beaver, mother, tv, series]
# 20409                                [Mount Gambier, Grampian Mountains, mountain, country]
# 21009                                                                           [patroness]
# 21609                                                        [Margaret Thatcher, area, day]
# 22209                                                                         [counterpart]
# 22809                                                                               [river]
# 23409                                                     [john vanbrugh, building, design]
# 24009                                                                                [city]
# 24609                                                        [duodenum, intestine, section]
# 25209                                                                  [word, country, use]
# 25809                                                                                    []
# 26409                                                         [spoof, chapter, author, sex]
# 27009                                                [don quixote, cervantes, broadway, s ]
# 27609                                                                     [v, day, date, e]
# 28209                                                                                    []
# 28809                                                           [grape, champagne, variety]
# ...
# 0  Types_of_country_subdivisions  29492692           NaN    NaN       NaN
# 1           Country_subdivisions   7531041           1.0  312.0  0.003205
# 2             Geography_by_place   5782300           0.0   30.0  0.000000
# 3                      Geography    693800           0.0  113.0  0.000000
# 4     Main_topic_classifications   7345184           0.0  118.0  0.000000
#
#    depth  similarityBAC mostSimilar               comment
# 0      4            NaN         NaN                   NaN
# 1      3            2.5        True  Lowest similarityBAC
# 2      2            2.0        True  Lowest similarityBAC
# 3      1            1.0        True  Lowest similarityBAC
# 4      0            0.0        True  Lowest similarityBAC
# 55809                    pages.title  pages.id  intersection    union   jaccard  \
# 0   American_male_film_actors  38422423           NaN      NaN       NaN
# 1        American_film_actors   2834619           0.0  10985.0  0.000000
# 2  Film_actors_by_nationality   3066616           1.0    167.0  0.005988
# 3  Film_people_by_nationality  41764593           0.0    322.0  0.000000
# 4           Cinema_by_country   2304964           0.0    368.0  0.000000
# 5    Entertainment_by_country   1371907           0.0    214.0  0.000000
# 6               Entertainment    693016           0.0    151.0  0.000000
# 7  Main_topic_classifications   7345184           0.0    148.0  0.000000
#
#    depth  similarityBAC mostSimilar  \
# 0      7            NaN         NaN
# 1      6            6.0        True
# 2      5            4.5        True
# 3      4            4.0        True
# 4      3            3.0        True
# 5      2            2.0        True
# 6      1            1.0        True   ...
# 56409                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     None
# 57009                                       pages.title  pages.id  intersection  \
# 0  National_Book_Award_for_Fiction_winning_works  34792411           NaN
# 1              National_Book_Award-winning_works  34896473           0.0
# 2                                 Books_by_award    933394           0.0
# 3                                          Books    694040           0.0
# 4                                     Humanities   1004110           0.0
# 5                     Main_topic_classifications   7345184           6.0
#
#    union  jaccard  depth  similarityBAC mostSimilar  \
# 0    NaN      NaN      5            NaN         NaN
# 1  114.0     0.00      4            4.0        True
# 2   84.0     0.00      3            3.0        True
# 3  101.0     0.00      2            2.0        True
# 4  141.0     0.00      1            1.0        True
# 5  100.0     0.06      0           -3.0        True
#
#                                                                          comm...
# 57609                    pages.title pages.id  intersection    union   jaccard  \
# 0      English-language_films  4826085           NaN      NaN       NaN
# 1           Films_by_language  1819414           1.0  57841.0  0.000017
# 2                       Films  4610114           0.0    261.0  0.000000
# 3                        Film  2012004           0.0     94.0  0.000000
# 4               Entertainment   693016           3.0    179.0  0.016760
# 5  Main_topic_classifications  7345184           0.0    148.0  0.000000
#
#    depth  similarityBAC mostSimilar  \
# 0      5            NaN         NaN
# 1      4            3.5        True
# 2      3            3.0        True
# 3      2            2.0        True
# 4      1           -0.5        True
# 5      0            0.0       False
#
#                                                                          comment
# 0                                                                            NaN
# 1                             ...
# 58209                                  pages.title  pages.id  intersection  union  \
# 0   Presidents_of_the_Trades_Union_Congress  25160174           NaN    NaN
# 1           Leaders_of_British_trade_unions   4684125          24.0  305.0
# 2                   British_trade_unionists   1493108           3.0  372.0
# 3                         British_activists   3068569           2.0  362.0
# 4                  Activists_by_nationality   3726086           3.0  394.0
# 5                                 Activists    905815           0.0  295.0
# 6                                  Activism    905806           1.0  275.0
# 7                             Social_change   3659012           4.0  244.0
# 8                             Social_issues   3659008           0.0  115.0
# 9                                   Society   1633936           0.0   94.0
# 10               Main_topic_classifications   7345184           0.0   62.0
#
#      jaccard  depth  similarityBAC mostSimilar             ...
# 58809                    pages.title pages.id  intersection   union   jaccard  depth  \
# 0          American_inventors  2909054           NaN     NaN       NaN      5
# 1    Inventors_by_nationality  1064365           1.0  2111.0  0.000474      4
# 2                   Inventors   745438           0.0   207.0  0.000000      3
# 3                  Inventions  1603571           0.0   169.0  0.000000      2
# 4                     History   693555           0.0    81.0  0.000000      1
# 5  Main_topic_classifications  7345184           1.0    65.0  0.015385      0
#
#    similarityBAC mostSimilar  \
# 0            NaN         NaN
# 1            3.5        True
# 2            3.0        True
# 3            2.0        True
# 4            1.0        True
# 5           -0.5        True
#
#                                                                          comment
# 0                                                                            NaN
# 1  Lowest similarityBAC; Lowest depth...
# 59409                    pages.title  pages.id  intersection  union   jaccard  depth  \
# 0         Kylie_Minogue_songs   1356148           NaN    NaN       NaN      6
# 1             Dance-pop_songs  12554595           2.0  879.0  0.002275      5
# 2           Dance_music_songs  44622349           0.0  819.0  0.000000      4
# 3                 Dance_music    940702           0.0  106.0  0.000000      3
# 4                       Dance    735385           0.0  108.0  0.000000      2
# 5               Entertainment    693016           0.0  163.0  0.000000      1
# 6  Main_topic_classifications   7345184           0.0  148.0  0.000000      0
#
#    similarityBAC mostSimilar               comment
# 0            NaN         NaN                   NaN
# 1            4.0        True  Lowest similarityBAC
# 2            4.0        True  Lowest similarityBAC
# 3            3.0        True  Lowest similarityBAC
# 4            2.0        True  Lowest similarityBAC
# 5            1.0        True ...
# 60009                                                                                                                                         pages.title pages.id  intersection  union   jaccard  depth  \
# 0                     Borders  1854524           NaN    NaN       NaN      4
# 1         Political_geography  1898464           6.0  144.0  0.041667      3
# 2       Branches_of_geography  5883021           1.0   88.0  0.011364      2
# 3                   Geography   693800           0.0  108.0  0.000000      1
# 4  Main_topic_classifications  7345184           0.0  118.0  0.000000      0
#
#    similarityBAC mostSimilar                             comment
# 0            NaN         NaN                                 NaN
# 1            0.0        True                Lowest similarityBAC
# 2            1.5        True  Lowest similarityBAC; Lowest depth
# 3            1.0        True                Lowest similarityBAC
# 4            0.0        True                Lowest similarityBAC
# 60609                     pages.title  pages.id  intersection   union   jaccard  \
# 0                     U2_songs   2305467           NaN     NaN       NaN
# 1              Songs_by_artist    692335           0.0  7678.0  0.000000
# 2                        Songs    696410           0.0  7583.0  0.000000
# 3              Oral_literature  27812268           0.0    52.0  0.000000
# 4               Oral_tradition  10382571           5.0    74.0  0.067568
# 5          Traditional_stories    694908           6.0    96.0  0.062500
# 6                   Traditions    696248           2.0   128.0  0.015625
# 7        Cultural_anthropology    715355           6.0   242.0  0.024793
# 8                 Anthropology    694863          12.0   545.0  0.022018
# 9                   Humanities   1004110           2.0   477.0  0.004193
# 10  Main_topic_classifications   7345184           6.0   100.0  0.060000
#
#     depth  similarityBAC mostSimilar  \
# 0       6            NaN         NaN
# 1  ...
# 61209                    pages.title  pages.id  intersection  union   jaccard  depth  \
# 0                    Genetics    696008           NaN    NaN       NaN      5
# 1         Branches_of_biology  37535091           0.0  683.0  0.000000      4
# 2                     Biology    692675           0.0  228.0  0.000000      3
# 3                   Organisms   8899078           1.0  179.0  0.005587      2
# 4                        Life   2389032           1.0   48.0  0.020833      1
# 5  Main_topic_classifications   7345184           0.0   49.0  0.000000      0
#
#    similarityBAC mostSimilar  \
# 0            NaN         NaN
# 1            4.0        True
# 2            3.0        True
# 3            1.5        True
# 4            0.5        True
# 5            0.0        True
#
#                                                                          comment
# 0                                                                            NaN
# 1                                    ...
# 61809                                                                                                                                                                                                                                                                                                                                                                       pages.title pages.id  intersection  union  jaccard  depth  \
# 0                     Slogans  2263780           NaN    NaN      NaN      3
# 1              Creative_works  7390225           0.0   82.0      0.0      2
# 2                        Arts  4892515           0.0  120.0      0.0      1
# 3  Main_topic_classifications  7345184           0.0  116.0      0.0      0
#
#    similarityBAC mostSimilar               comment
# 0            NaN         NaN                   NaN
# 1            2.0        True  Lowest similarityBAC
# 2            1.0        True  Lowest similarityBAC
# 3            0.0       False
# 62409                                   pages.title  pages.id  intersection  union  \
# 0                      Jewish_ritual_objects  13919543           NaN    NaN
# 1                     Jewish_law_and_rituals    733070           3.0  141.0
# 2                 Jewish_belief_and_doctrine  30683712           5.0  113.0
# 3  Religious_belief_and_doctrine_by_religion  37526511           0.0   24.0
# 4                     Categories_by_religion  10471677           0.0   32.0
# 5                                   Religion    692694           0.0  109.0
# 6                 Main_topic_classifications   7345184           0.0  110.0
#
#     jaccard  depth  similarityBAC mostSimilar  \
# 0       NaN      4            NaN         NaN
# 1  0.021277      4            2.5        True
# 2  0.044248      4            1.5        True
# 3  0.000000      3            3.0        True
# 4  0.000000      2            2.0        True
# 5  0.000000      1            1.0        True
# 6  0.000000      0  ...
# 63009                    pages.title pages.id  intersection  union   jaccard  depth  \
# 0        Christmas_characters  1051624           NaN    NaN       NaN      5
# 1          Holiday_characters  9651111           5.0  104.0  0.048077      4
# 2         Legendary_creatures   706923           0.0   65.0  0.000000      3
# 3                    Folklore   728925           2.0  222.0  0.009009      2
# 4         Traditional_stories   694908          13.0  227.0  0.057269      3
# 5                  Traditions   696248           2.0  128.0  0.015625      2
# 6       Cultural_anthropology   715355           6.0  242.0  0.024793      2
# 7                Anthropology   694863          12.0  545.0  0.022018      2
# 8                  Humanities  1004110           2.0  477.0  0.004193      1
# 9  Main_topic_classifications  7345184           6.0  100.0  0.060000      0
#
#    similarityBAC mostSimilar                             comment
# 0            NaN         NaN                    ...
# 63609                    pages.title  pages.id  intersection  union   jaccard  depth  \
# 0        Mollusc_common_names  55849638           NaN    NaN       NaN      7
# 1   Invertebrate_common_names  47951108           0.0   28.0  0.000000      6
# 2         Animal_common_names  21143238           0.0   15.0  0.000000      5
# 3                     Animals    716885           0.0   38.0  0.000000      4
# 4                  Eukaryotes   2048900           0.0   46.0  0.000000      3
# 5                   Organisms   8899078           0.0   37.0  0.000000      2
# 6                        Life   2389032           1.0   48.0  0.020833      1
# 7  Main_topic_classifications   7345184           0.0   49.0  0.000000      0
#
#    similarityBAC mostSimilar  \
# 0            NaN         NaN
# 1            6.0        True
# 2            5.0        True
# 3            4.0        True
# 4            3.0        True
# 5            2.0        True
# 6            0.5        True
# 7         ...
# 64209                    pages.title  pages.id  intersection  union   jaccard  depth  \
# 0         Automotive_industry   1338498           NaN    NaN       NaN      5
# 1         Transport_economics   3646902           1.0  183.0  0.005464      4
# 2            Public_economics   4826313           0.0  168.0  0.000000      3
# 3               Public_sphere  46279088           1.0  206.0  0.004854      2
# 4                     Society   1633936           0.0  160.0  0.000000      1
# 5  Main_topic_classifications   7345184           0.0   62.0  0.000000      0
#
#    similarityBAC mostSimilar  \
# 0            NaN         NaN
# 1            3.5        True
# 2            3.0        True
# 3            1.5        True
# 4            1.0        True
# 5            0.0        True
#
#                                                                          comment
# 0                                                                            NaN
# 1  Lowest similarityBAC; Lowest depth...

# %%
articleID = categoryByTitle("Dallas_Stars")
childPages(articleID.iloc[0,1])
# Out:
#                              pages.title  pages.id
# 0   Dallas_Stars_minor_league_affiliates  44888329
# 1               Dallas_Stars_draft_picks   6786253
# 2                  Minnesota_North_Stars   1291349
# 3                 Dallas_Stars_templates  43251887
# 4                           Dallas_Stars     73135
# 5              Dallas_Stars_broadcasters  24358568
# 6                   Dallas_Stars_seasons   8599536
# 7                     Dallas_Stars_lists  44913547
# 8                 Dallas_Stars_personnel  40381465
# 9                           Paul_Fioroni  40260405
# 10               1999_Stanley_Cup_Finals   2082964
# 11                   Dallas_Stars_arenas  24894192
# 12               2000_Stanley_Cup_Finals   1598577

# %%
# %%time
getWikipediaInfo("Tutankhamun")
# Out:
# Wall time: 5.59 s
# <ipython-input-25-0b2f5f3b6b43>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   workingDF["mostSimilar"] = "False"
# ['Tutankhamun',
#  30437,
#                     pages.title  pages.id  intersection  union   jaccard  \
#  0                Amarna_Period   2285457           NaN    NaN       NaN
#  1  Eighteenth_Dynasty_of_Egypt  35203613           0.0   94.0  0.000000
#  2   Dynasties_of_ancient_Egypt   7869122           1.0   98.0  0.010204
#  3                Ancient_Egypt    722461           1.0  161.0  0.006211
#  4                Civilizations   3255048           0.0  148.0  0.000000
#  5        Cultural_anthropology    715355           2.0  222.0  0.009009
#  6                 Anthropology    694863          12.0  545.0  0.022018
#  7                   Humanities   1004110           2.0  477.0  0.004193
#  8   Main_topic_classifications   7345184           6.0  100.0  0.060000
#
#     depth  similarityBAC mostSimilar  \
#  0      7            NaN         NaN
#  1      6            6.0        True
#  2      5            4.5        True
#  3      4            3.5        True
#  4      3            3.0        True
#  5      2            1.0        True
#  6      2           -4.0        True
#  7      1            0.0        True
#  8      0           -3.0        True
#
#                                                                           comment
#  0                                                                            NaN
#  1                                                           Lowest similarityBAC
#  2  Lowest similarityBAC; Lowest depth; Highest intersection; Lowest wikipedia id
#  3                                                           Lowest similarityBAC
#  4                                                           Lowest similarityBAC
#  5                                                           Lowest similarityBAC
#  6                                                           Lowest similarityBAC
#  7                                             Lowest similarityBAC; Lowest depth
#  8                                                           Lowest similarityBAC  ,
#                                                      pages.title  pages.id
#  0         Historical_people_who_were_forensically_reconstructed  47159604
#  1                        Royalty_and_nobility_with_disabilities  42793677
#  2                                                       Atenism  12814260
#  3                                      Ancient_Egyptian_mummies  21811075
#  4                                                   Tutankhamun  42963890
#  5           Pages_containing_links_to_subscription-only_content  39181053
#  6   Commons_category_with_local_link_different_than_on_Wikidata  39217578
#  7                                           Deaths_from_malaria   8904739
#  8                                                        Curses   1149577
#  9                                                 Amarna_Period   2285457
#  10                  Pharaohs_of_the_Eighteenth_Dynasty_of_Egypt  35203638
#  11                                  Use_dmy_dates_from_May_2014  42623245
#  12                                         Ancient_child_rulers  17283488]

# %%
articleByTitle("Dallas_Stars")
# Out:
#   articles.title  articles.id  ID(articles)
# 0   Dallas_Stars        73135        199548

# %%
categoryByTitle("New_York")
# Out:
#   categories.title  categories.id  ID(categories)
# 0         New_York       54615728         7336710

# %%
chosenPathUpToMTC(19022484)
# Out:
# <ipython-input-25-0b2f5f3b6b43>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   workingDF["mostSimilar"] = "False"
#                   pages.title  pages.id  intersection  union   jaccard  depth  \
# 0      States_by_power_status  12318463             4     82  0.048780      3
# 1                Independence  40105099             6     58  0.103448      3
# 2                 Sovereignty  33542662             8    118  0.067797      4
# 3           International_law    700660            15    418  0.035885      3
# 4     International_relations    918476            10    568  0.017606      4
# 5              Foreign_policy  19025423            11    280  0.039286      4
# 6               Public_policy  19025271             3    122  0.024590      3
# 7                  Government    697609             3    231  0.012987      2
# 8                    Politics    695027             3    234  0.012821      1
# 9  Main_topic_classifications   7345184             0    115  0.000000      0
#
#    similarityBAC mostSimilar                             comment
# 0            1.0        True                Lowest similarityBAC
# 1            0.0        True  Lowest similarityBAC; Lowest depth
# 2            0.0        True                Lowest similarityBAC
# 3           -4.5        True                Lowest similarityBAC
# 4           -1.0        True                Lowest similarityBAC
# 5           -1.5        True                Lowest similarityBAC
# 6            1.5        True                Lowest similarityBAC
# 7            0.5        True  Lowest similarityBAC; Lowest depth
# 8           -0.5        True                Lowest similarityBAC
# 9            0.0       False

# %%
parentCategories(722461)
# Out:
#                        pages.title  pages.id
# 0                      Superpowers  19022484
# 1                   Ancient_Africa  41255972
# 2               Iron_Age_countries  55467935
# 3                    Civilizations   3255048
# 4       History_of_Egypt_by_period   9444719
# 5             Bronze_Age_countries  55467948
# 6            African_civilizations  11277046
# 7  Ancient_history_of_North_Africa  48859080
# 8       Ancient_history_by_country  10803059

# %%
parentSimilarities(722461)
# Out:
#                        pages.title  pages.id  intersection  union   jaccard  \
# 0                    Civilizations   3255048             0    148  0.000000
# 1                      Superpowers  19022484             1    122  0.008197
# 2       History_of_Egypt_by_period   9444719             1    108  0.009259
# 3            African_civilizations  11277046             1    116  0.008621
# 4       Ancient_history_by_country  10803059             0    141  0.000000
# 5                   Ancient_Africa  41255972             0     96  0.000000
# 6               Iron_Age_countries  55467935             0     88  0.000000
# 7             Bronze_Age_countries  55467948             0     88  0.000000
# 8  Ancient_history_of_North_Africa  48859080             0    101  0.000000
#
#    depth  similarityBAC
# 0      3            3.0
# 1      4            3.5
# 2      4            3.5
# 3      4            3.5
# 4      4            4.0
# 5      5            5.0
# 6      5            5.0
# 7      5            5.0
# 8      5            5.0
